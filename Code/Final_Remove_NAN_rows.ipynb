# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/Projects/FoodDataset/IndianFoodDataset2.csv')

# %%
df.shape
# Out:
# (14230, 15)

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (14206, 15)

# %%
df1.to_csv('/content/drive/My Drive/Projects/FoodDataset/IndianFoodDataset3.csv')
