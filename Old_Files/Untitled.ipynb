# %%
import numpy as np
import pandas as pd

# %%
test_df = pd.read_csv('IndianFoodDatasetCSV.csv')

# %%
test_df.na
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 14225       14225         14225
# 14226       14226         14226
# 14227       14227         14227
# 14228       14228         14228
# 14229       14229         14229
#
#                                               RecipeName  \
# 0                                   Masala Karela Recipe
# 1      टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2      Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3      Gongura Chicken Curry Recipe - Andhra Style Go...
# 4      आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
# ...                                                  ...
# 14225  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 14226  Shimla Mirchi Panchamrut Recipe | Konkani Caps...
# ...

# %%
test_df1 = test_df[test_df.isna().any(axis=1)]

# %%
test_df.shape
# Out:
# (14230, 15)

# %%
test_df.dropna()
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 14213       14213         14213
# 14214       14214         14214
# 14215       14215         14215
# 14216       14216         14216
# 14217       14217         14217
#
#                                               RecipeName  \
# 0                                   Masala Karela Recipe
# 1      टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2      Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3      Gongura Chicken Curry Recipe - Andhra Style Go...
# 4      आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
# ...                                                  ...
# 14213       हलीम के कबाब रेसिपी - Haleem Ke Kebab Recipe
# 14214  Bihari Style Baingan Ka Chokha Recipe (Smoked ...
# ...
